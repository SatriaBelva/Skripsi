# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline

# %%
df = pd.read_csv("dataset.csv")
# dataset_xlsx = pd.read_excel("dataset.xlsx")
df.head(10)
df.tail(10)
# Out:
#         Name  Age  Income
# 140  Mahmoud   47  205000
# 141   Fatima   22   27000
# 142    Aisha   26   47000
# 143   Mariam   30   76000
# 144     Noor   34  101000
# 145    Layla   39  143000
# 146   Zainab   42  165000
# 147    Salma   50  272000
# 148    Amira   57  335000
# 149    Rania   60  350000

# %%
plt.scatter(df['Age'],df['Income'])

# %%
km = KMeans(n_clusters=3)
km
# Out:
# KMeans(n_clusters=3)

# %%
y_prediction = km.fit_predict(df[['Age','Income']])
y_prediction
# Out:
# c:\Users\satri\AppData\Local\Programs\Python\Python313\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# found 0 physical cores < 1
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\satri\AppData\Local\Programs\Python\Python313\Lib\site-packages\joblib\externals\loky\backend\context.py", line 282, in _count_physical_cores
#     raise ValueError(f"found {cpu_count_physical} physical cores < 1")
# array([2, 2, 2, 2, 0, 0, 0, 0, 0, 0, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 0, 0, 1, 2, 2, 2, 2, 2, 0, 0, 1, 2, 0, 2, 0, 0, 2, 2,
#        0, 0, 1, 0, 1, 2, 0, 1, 2, 2, 2, 2, 0, 0, 1, 2, 2, 2, 0, 2, 0, 0,
#        1, 2, 0, 2, 0, 0, 2, 2, 0, 0, 1, 0, 1, 2, 0, 1, 2, 2, 2, 2, 0, 0,
#        1, 2, 2, 2, 0, 2, 0, 0, 1, 2, 0, 2, 0, 0, 2, 2, 0, 0, 1, 0, 1, 2,
#        0, 1, 2, 2, 2, 0, 0, 1, 2, 2, 0, 0, 2, 2, 2, 0, 0, 0, 1, 1, 1, 2,
#        2, 2, 0, 0, 1, 2, 0, 0, 0, 2, 2, 2, 0, 0, 0, 1, 1, 1], dtype=int32)
